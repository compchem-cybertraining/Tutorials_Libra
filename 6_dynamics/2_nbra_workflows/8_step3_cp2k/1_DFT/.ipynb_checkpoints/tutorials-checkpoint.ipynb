# %% [markdown]
# # Computing the nonadiabatic couplings in Kohn-Sham and excited states bases
#
# In this tutorial, we will start computing the nonadiabatic couplings (NACs) from the molecular orbital overlap files obtained in [step2](../../7_step2_cp2k/1_DFT). The NACs will be computed in Kohn-Sham states and also in both single-partcile (SP) and many-body (MB) excited state bases. Finally we will plot the excited states energies vs time and NAC map.
#
# ## Table of contents
# <a name="toc"></a>
# 1. [Importing needed libraries](#import)
# 2. [Overview of required files](#required_files)
# 3. [Computing the NACs](#comp_nacs)
#     3.1. [Kohn-Sham basis](#KS)\
#     3.2. [Excited state basis](#excited_states)
# 4. [Plotting the results](#plotting)\
#     4.1. [NAC distribution](#nac_dist)\
#     4.2. [Energy vs time](#ene_time)\
#     4.3. [NAC map](#nac_map)
#
# ### A. Learning objectives
#
# * To be able to compute the NACs in Kohn-Sham and excited state bases
# * To be able to plot the NACs distribution
# * To be able to plot the computed excited states energies vs time
# * To be able to plot the NAC map
#
# ### B. Use cases
#
# * [Computing the NACs](#comp_nacs)
# * [Plotting the results](#plotting)
#
#
# ### C. Functions
#
# - `libra_py`
#   - `data_stat`
#     -  `cmat_distrib`
#   - `workflows`
#     - `nbra`
#       - [`step3`](#comp_nacs)
#         - [`run_step3_ks_nacs_libint`](#KS)
#         - [`run_step3_sd_nacs_libint`](#excited_states)
#   - `units`
#     - `au2ev`

# %% [markdown]
# ## 1. Importing needed libraries <a name="import"></a>
# [Back to TOC](#toc)
#
# Since the data are stored in sparse format using `scipy.sparse` library, we need to load this library so that we can read and check the orthonormality of the data.
# Import `numpy`, `scipy.sparse`, `data_stat`, `data_io`, `units`, and `step3` modules. Also, `glob` will be needed to find specific types of files.

# %%
import os
import sys
import time
import glob
import numpy as np
import scipy.sparse as sp
import matplotlib.pyplot as plt
from liblibra_core import *
from libra_py.workflows.nbra import step3
from libra_py import units, data_stat, data_io
# Out:
# /projects/academic/alexeyak/mohammad/software/miniconda3/envs/libra/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /projects/academic/alexeyak/mohammad/software/miniconda3/envs/libra/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for boost::python::detail::container_element<std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > >, unsigned long, boost::python::detail::final_vector_derived_policies<std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > >, false> > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /projects/academic/alexeyak/mohammad/software/miniconda3/envs/libra/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for std::vector<std::vector<float, std::allocator<float> >, std::allocator<std::vector<float, std::allocator<float> > > > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /projects/academic/alexeyak/mohammad/software/miniconda3/envs/libra/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for boost::python::detail::container_element<std::vector<std::vector<float, std::allocator<float> >, std::allocator<std::vector<float, std::allocator<float> > > >, unsigned long, boost::python::detail::final_vector_derived_policies<std::vector<std::vector<float, std::allocator<float> >, std::allocator<std::vector<float, std::allocator<float> > > >, false> > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /projects/academic/alexeyak/mohammad/software/miniconda3/envs/libra/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for std::vector<std::vector<double, std::allocator<double> >, std::allocator<std::vector<double, std::allocator<double> > > > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /projects/academic/alexeyak/mohammad/software/miniconda3/envs/libra/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for boost::python::detail::container_element<std::vector<std::vector<double, std::allocator<double> >, std::allocator<std::vector<double, std::allocator<double> > > >, unsigned long, boost::python::detail::final_vector_derived_policies<std::vector<std::vector<double, std::allocator<double> >, std::allocator<std::vector<double, std::allocator<double> > > >, false> > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /projects/academic/alexeyak/mohammad/software/miniconda3/envs/libra/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for std::vector<std::vector<std::complex<double>, std::allocator<std::complex<double> > >, std::allocator<std::vector<std::complex<double>, std::allocator<std::complex<double> > > > > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /projects/academic/alexeyak/mohammad/software/miniconda3/envs/libra/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for boost::python::detail::container_element<std::vector<std::vector<std::complex<double>, std::allocator<std::complex<double> > >, std::allocator<std::vector<std::complex<double>, std::allocator<std::complex<double> > > > >, unsigned long, boost::python::detail::final_vector_derived_policies<std::vector<std::vector<std::complex<double>, std::allocator<std::complex<double> > >, std::allocator<std::vector<std::complex<double>, std::allocator<std::complex<double> > > > >, false> > already registered; second conversion method ignored.
#   return f(*args, **kwds)

# %% [markdown]
# ## 2. Overview of required files <a name="required_files"></a>
# [Back to TOC](#toc)
#
# * `../../7_step2_cp2k/1_DFT/2_hpc/res`
#
# The MO overlap files are needed and stored in this folder.
#
# * `../../7_step2_cp2k/1_DFT/2_hpc/all_logfiles`
#
# All of the logfiles obtained from the electronic structure calculations of CP2K. These files will be needed to find the Kohn-Sham HOMO index and also extract the the TD-DFT data for each step.

# %% [markdown]
# ## 3. Computing the NACs <a name="comp_nacs"></a>
# [Back to TOC](#toc)
#
# ### 3.1. Kohn-Sham basis <a name="KS"></a>
#
# The `libra_py.workflow.nbra.step3.run_step3_ks_nacs_libint(params)` computes the NACs between pairs of Kohn-Sham states using the molecular orbital
# overlaps. The paramters for this function are as follows:
#
# `params['lowest_orbital']`: The lowest orbital considered in the computation of the MO overlaps. This value is exactly the same
# as in the `run_template.py` file in step2.
#
# `params['highest_orbital']`: The highest orbital considered in the computation of the MO overlaps. This value is exactly the same
# as in the `run_template.py` file in step2.
#
# `params['num_occ_states']`: The number of occupied orbitals to be considered from HOMO to lower occupied states. This value is defined by user.
#
# `params['num_unocc_states']`: The number of unoccupied orbitals to be considered from LUMO to higher unoccupied states. This value is defined by user.
#
# The two values above are used to create an active space which then will be used to select the elements from the MO overlap and energy matrices.
#
# `params['use_multiprocessing']`: A boolean flag to use the multiprocessing library of Python or not.
#
# `params['nprocs']`: The number of processors to be used for the calculations. Libra will use this only if the `params['use_multiprocessing']`
# is set to `True`.
#
# `params['time_step']`: The time-step used in the calculations in `fs`.
#
# `params['es_software']`: The name of the software package used to compute the electronic structure calculations. This will be used to generate the HOMO
# index of that system so it can build the active space.
#
# `params['path_to_npz_files']`: The full path to the MO overlap files.
#
# `params['logfile_directory']`: The full path to the folder where all the log files are stored.
#
# `params['path_to_save_ks_Hvibs']`: The full path to the folder in which the NACs between the Konh-Sham states are stored.
#
# `params['start_time']`: The start time-step.
#
# `params['finish_time']`: The finish time-step.
#
# `params['apply_phase_correction']`: A boolean flag for applying phase-correction algorithm.
#
# `params['apply_orthonormalization']`: A boolean flag for applying the orthonormalization algorithm.
#
# `params['do_state_reordering']`: If this value is set to `1` or `2`, the state-reordering will be applied to overlap matrices.
#
# `params['state_reordering_alpha']`: The state-reordering alpha value if the `params['do_state_reordering'] = 2`.
#
# After setting all the above paramters, the calculations are run using `step3.run_step3_ks_nacs_libint(params)`.

# %%
params_ks = {
          'lowest_orbital': 24-10, 'highest_orbital': 24+11, 'num_occ_states': 10, 'num_unocc_states': 10,
          'use_multiprocessing': True, 'nprocs': 4, 'time_step': 1.0, 'es_software': 'cp2k',
          'path_to_npz_files': os.getcwd()+'/../../7_step2_cp2k/1_DFT/2_hpc/res',
          'logfile_directory': os.getcwd()+'/../../7_step2_cp2k/1_DFT/2_hpc/all_logfiles',
          'path_to_save_ks_Hvibs': os.getcwd()+'/res-ks',
          'start_time': 1, 'finish_time': 49,
          'apply_phase_correction': True, 'apply_orthonormalization': True,
          'do_state_reordering': 2, 'state_reordering_alpha':0
         }

#### For KS states - Applying correction to KS overlaps and computing the NACs in KS space
step3.run_step3_ks_nacs_libint(params_ks)
# Out:
# Computing orthonormalization of St matrices in stepComputing orthonormalization of St matrices in stepComputing orthonormalization of St matrices in stepComputing orthonormalization of St matrices in step    17410
#
#
#
# Done with step 1 Done with step. Elapsed time:  12.9072346687316910
#  Computing orthonormalization of St matrices in step. Elapsed time:  212.910395622253418
#
# Computing orthonormalization of St matrices in step 11
# Done with step 2 . Elapsed time: 0.33025312423706055
# Computing orthonormalization of St matrices in step 3
# Done with step 3 . Elapsed time: 0.0733799934387207
# Computing orthonormalization of St matrices in step 13
# Done with step 4 . Elapsed time: 13.922582149505615
# Computing orthonormalization of St matrices in step 5
# Done with step 7 . Elapsed time: 13.97711968421936
# Computing orthonormalization of St matrices in step 8
# Done with step 8 . Elapsed time: 1.1298959255218506
# Computing orthonormalization of St matrices in step 9
# Done with step 11 . Elapsed time: 2.4125263690948486
# Computing orthonormalization of St matrices in step 12
# Done with step 5 . Elapsed time:Done with step  6.40327835083007813
#  Computing orthonormalization of St matrices in step. Elapsed time:  67.0041913986206055
#
# Computing orthonormalization of St matrices in step 14
# Done with step 9 . Elapsed time: 5.3021063804626465
# Done with step Computing orthonormalization of St matrices in step 616
# . Elapsed time: 0.0909268856048584
# Computing orthonormalization of St matrices in step 19
# Done with step 12 . Elapsed time: 5.17420506477356
# Computing orthonormalization of St matrices in step 22
# Done with step Done with step19  . Elapsed time: 140.1689622402191162
#  Computing orthonormalization of St matrices in step . Elapsed time:20
# 0.25893306732177734
# Computing orthonormalization of St matrices in step Done with stepDone with step15
# 2216  . Elapsed time: 0.2259082794189453
# Computing orthonormalization of St matrices in step . Elapsed time:17
#  0.11396121978759766
# Computing orthonormalization of St matrices in step 23
# Done with step 20 . Elapsed time: 0.09001827239990234
# Computing orthonormalization of St matrices in step 21
# Done with step 17 . Elapsed time:Done with stepDone with step  0.1367034912109375 15
# Computing orthonormalization of St matrices in step 23 . Elapsed time:18
# . Elapsed time:0.19101548194885254
#  Computing orthonormalization of St matrices in step0.1530759334564209
# 25Computing orthonormalization of St matrices in step
#  Done with step24
# 21 . Elapsed time: 0.1214141845703125
# Computing orthonormalization of St matrices in step 28
# Done with step 18 Done with step. Elapsed time:  240.12775373458862305 . Elapsed time:
#  Computing orthonormalization of St matrices in step0.13362693786621094
#  Computing orthonormalization of St matrices in step31 34
#
# Done with step 25 . Elapsed time: 0.3527963161468506
# Computing orthonormalization of St matrices in step 26
# Done with step Done with step28 34 . Elapsed time:  . Elapsed time:0.19568562507629395
#  Computing orthonormalization of St matrices in step0.33241987228393555
# 35Computing orthonormalization of St matrices in step
#  29
# Done with step 26 . Elapsed time: 0.08737754821777344
# Computing orthonormalization of St matrices in step 27
# Done with step 35 . Elapsed time: 0.10214567184448242
# Done with stepComputing orthonormalization of St matrices in step  2936
#  . Elapsed time:Done with step  0.1314537525177002
# Computing orthonormalization of St matrices in step 30
# 31 . Elapsed time: 0.3976266384124756Done with step
# Computing orthonormalization of St matrices in step  2732
#  . Elapsed time: Done with step 0.1336483955383300830
# Computing orthonormalization of St matrices in stepDone with step   . Elapsed time:3637
#   0.10832953453063965. Elapsed time:
# Computing orthonormalization of St matrices in stepDone with step  400.17212200164794922
#
# Computing orthonormalization of St matrices in step  32 43
# . Elapsed time: Done with step0.13539600372314453
#  Computing orthonormalization of St matrices in step37  33. Elapsed time:
#  0.09635519981384277
# Computing orthonormalization of St matrices in step 38
# Done with step Done with step40  Done with step. Elapsed time: 43 380.2022557258605957
# . Elapsed time: Done with stepComputing orthonormalization of St matrices in step0.13590192794799805. Elapsed time:
#  33Computing orthonormalization of St matrices in step  . Elapsed time:   0.16803145408630374139
#
# Computing orthonormalization of St matrices in step0.17375969886779785
#  46
#
# Computing orthonormalization of St matrices in step 44
# Done with step 39 . Elapsed time: 0.1270291805267334
# Done with step Done with step41  46 . Elapsed time:. Elapsed time:  Done with step0.18918371200561523 0.20563101768493652
# 44
# Computing orthonormalization of St matrices in step  42Computing orthonormalization of St matrices in step. Elapsed time:
#  0.21018075942993164
# Computing orthonormalization of St matrices in step 45
# 47
# Done with step 42 . Elapsed time: 0.09641718864440918
# Done with step Done with step47  . Elapsed time: 0.13885092735290527
# 45Computing orthonormalization of St matrices in step  48. Elapsed time:
#  0.14316534996032715
# Done with step 48 . Elapsed time: 0.08801007270812988
# Done with orthonormalization step. Elapsed time: 22.532180070877075
# Done with state-reordering of the KS orbitals. Elapsed time: 2.7486772537231445
# Performing phase correction...
# Applying phase-correction to step 1
# Applying phase-correction to step 2
# Applying phase-correction to step 3
# Applying phase-correction to step 4
# Applying phase-correction to step 5
# Applying phase-correction to step 6
# Applying phase-correction to step 7
# Applying phase-correction to step 8
# Applying phase-correction to step 9
# Applying phase-correction to step 10
# Applying phase-correction to step 11
# Applying phase-correction to step 12
# Applying phase-correction to step 13
# Applying phase-correction to step 14
# Applying phase-correction to step 15
# Applying phase-correction to step 16
# Applying phase-correction to step 17
# Applying phase-correction to step 18
# Applying phase-correction to step 19
# Applying phase-correction to step 20
# Applying phase-correction to step 21
# Applying phase-correction to step 22
# Applying phase-correction to step 23
# Applying phase-correction to step 24
# Applying phase-correction to step 25
# Applying phase-correction to step 26
# Applying phase-correction to step 27
# Applying phase-correction to step 28
# Applying phase-correction to step 29
# Applying phase-correction to step 30
# Applying phase-correction to step 31
# Applying phase-correction to step 32
# Applying phase-correction to step 33
# Applying phase-correction to step 34
# Applying phase-correction to step 35
# Applying phase-correction to step 36
# Applying phase-correction to step 37
# Applying phase-correction to step 38
# Applying phase-correction to step 39
# Applying phase-correction to step 40
# Applying phase-correction to step 41
# Applying phase-correction to step 42
# Applying phase-correction to step 43
# Applying phase-correction to step 44
# Applying phase-correction to step 45
# Applying phase-correction to step 46
# Applying phase-correction to step 47
# Applying phase-correction to step 48
# Done with phase correction. Elapsed time: 46.206364154815674

# %% [markdown]
# ### 3.2. Excited state basis <a name="excited_states"></a>
#
# The NACs can also be computed between excited states. These include the single-particle and many-body bases which the latter is obtained from the
# TD-DFT calculations. First, we need to compute the overlap between excited state Slater-determinants (SDs) then they will be used to compute the NACs
# between them. For many-body states, the configuration interaction coefficietns will also be used. We will consider both single-particle
# and many-body for DFT calculations but only single-particle for xTB.
#
# To run the calculations `step3.run_step3_sd_nacs_libint(params)` function will be used. Some parameters are common with the ones used to run `step3.run_step3_ks_nacs_libint(params)`.
#
# There are different ways of defining the excited states SDs (the single-particle excited state basis). The first is through
# defining the `num_occ_states` and `num_unocc_states` in which Libra
# will start making the SDs from all of the occupied states (starting from `HOMO-num_occ_states+1`) to all of the unoccupied states (ends
# to `LUMO+num_unocc_states-1`). Also, if the unrestricted spin calculation flag is set to `True`, the SDs will be made for both alpha and beta spin channels.
#
# For example, if you want to build the electron-only excitation basis, you need to set `params['num_occ_states'] = 1` and set `params['num_unocc_states']`
# to a value less than the number of unoccupied orbitals that was considered in the computation of overlaps. This will generate all the electron-only
# excitation from HOMO to unoccupied states.
#
# If the TD-DFT calculations has been done, then Libra will go over all log files and
# generate all the SDs used for all the steps and therefore the definition of these SDs is automatic and Libra will replace the `num_occ_states` and
# `num_unocc_states` itself based on the SDs that were generated from the TD-DFT log files.
#
#
#
# Other parameters needed to run the `step3.run_step3_sd_nacs_libint(params)` function are as follows:
#
# `params['isUKS']`: A boolean flag for unrestricted spin calculations.
#
# `params['is_many_body']`: If set to `True`, the NACs will be computed between pairs of many-body (TD-DFT) states. Also, the NACs between single-particle
# SDs obtained from the TD-DFT results will be computed as well. Otherwise, only single-particle NACs will be computed only for the SDs obtained from
# `num_occ_states` and `num_unocc_states`. This will be used for xTB calculations in which no TD-DFT is performed.
#
# `params['number_of_states']`: The number of TD-DFT states to consider. This value should not exceed the number of requested TD-DFT states in the CP2K
# calculations.
#
# `params['tolerance']`: A lower bound for selection of the excitation with configuration interaction coefficients higher than this value.
#
# `params['verbosity']`: An integer value showing the printing level. The default is set to 0. Higher values will print more data on terminal.
#
# `params['sorting_type']`: After defining the SDs, Libra will sort them either based on `'energy'` or `'identity'`.

# %%
#### For excited states - Computing the excited states SDs and their overlaps and NACs
params_mb_sd = {
          'lowest_orbital': 24-10, 'highest_orbital': 24+11, 'num_occ_states': 10, 'num_unocc_states': 10,
          'isUKS': 0, 'number_of_states': 5, 'tolerance': 0.01, 'verbosity': 0,
          'use_multiprocessing': True, 'nprocs': 4,
          'is_many_body': True, 'time_step': 1.0, 'es_software': 'cp2k',
          'path_to_npz_files': os.getcwd()+'/../../7_step2_cp2k/1_DFT/2_hpc/res',
          'logfile_directory': os.getcwd()+'/../../7_step2_cp2k/1_DFT/2_hpc/all_logfiles',
          'path_to_save_sd_Hvibs': os.getcwd()+'/res-mb-sd',
          'outdir': os.getcwd()+'/res-mb-sd',
          'start_time': 1, 'finish_time': 49, 'sorting_type': 'identity',
          'apply_phase_correction': True, 'apply_orthonormalization': True,
          'do_state_reordering': 2, 'state_reordering_alpha':0
         }


step3.run_step3_sd_nacs_libint(params_mb_sd)
# Out:
# sd_unique_basis is: [[[24, 25], 'alp'], [[23, 25], 'alp'], [[22, 25], 'alp'], [[24, 27], 'alp'], [[24, 28], 'alp'], [[24, 26], 'alp'], [[24, 29], 'alp'], [[21, 25], 'alp'], [[23, 26], 'alp'], [[23, 27], 'alp'], [[21, 28], 'alp'], [[22, 26], 'alp'], [[23, 29], 'alp'], [[22, 27], 'alp'], [[21, 26], 'alp'], [[22, 28], 'alp']]
# sd_states_reindexed is: [[1, -1, 2, -2, 3, -3, 4, -4], [1, -1, 2, -2, 3, -3, 5, -4], [1, -1, 2, -2, 5, -3, 4, -4], [1, -1, 5, -2, 3, -3, 4, -4], [1, -1, 2, -2, 3, -3, 7, -4], [1, -1, 2, -2, 3, -3, 8, -4], [1, -1, 2, -2, 3, -3, 6, -4], [1, -1, 2, -2, 3, -3, 9, -4], [5, -1, 2, -2, 3, -3, 4, -4], [1, -1, 2, -2, 6, -3, 4, -4], [1, -1, 2, -2, 7, -3, 4, -4], [8, -1, 2, -2, 3, -3, 4, -4], [1, -1, 6, -2, 3, -3, 4, -4], [1, -1, 2, -2, 9, -3, 4, -4], [1, -1, 7, -2, 3, -3, 4, -4], [6, -1, 2, -2, 3, -3, 4, -4], [1, -1, 8, -2, 3, -3, 4, -4]]
# ks_homo_index 24
# ks_orbital_indicies range(21, 30)
# Sorting and computing the SDs energies...
# Done with sorting and computing the SDs energies. Elapsed time: 1.5448458194732666
# Computing the SD overlaps for stepComputing the SD overlaps for stepComputing the SD overlaps for stepComputing the SD overlaps for step    0396
#
#
#
# Applying orthonormalization for SDs for stepApplying orthonormalization for SDs for step  6Applying orthonormalization for SDs for stepApplying orthonormalization for SDs for step9
#
# 30
#
# Done with computing the SD overlap of step 0. Elapsed time 0.11225533485412598
# Computing the SD overlaps for step 1
# Done with computing the SD overlap of step 9. Elapsed time 0.12032628059387207
# Computing the SD overlaps for step 10
# Done with computing the SD overlap of step 6. Elapsed time 0.12665224075317383
# Computing the SD overlaps for step 7
# Done with computing the SD overlap of step 3. Elapsed time 0.1364121437072754
# Computing the SD overlaps for step 4
# Applying orthonormalization for SDs for step 1
# Done with computing the SD overlap of step 1. Elapsed time 0.02515864372253418
# Computing the SD overlaps for step 2Applying orthonormalization for SDs for step
#  10
# Applying orthonormalization for SDs for step 7Applying orthonormalization for SDs for step
# Done with computing the SD overlap of step 10. Elapsed time 0.027463436126708984 4
#
# Computing the SD overlaps for step 11
# Done with computing the SD overlap of step 7. Elapsed time 0.026965618133544922
# Done with computing the SD overlap of step 4. Elapsed time 0.023554325103759766
# Computing the SD overlaps for step Computing the SD overlaps for step8
# 5
# Applying orthonormalization for SDs for step 2
# Done with computing the SD overlap of step 2. Elapsed time 0.020774126052856445
# Applying orthonormalization for SDs for step Computing the SD overlaps for step11
# 12
# Done with computing the SD overlap of step 11. Elapsed time 0.0198519229888916
# Applying orthonormalization for SDs for stepComputing the SD overlaps for stepApplying orthonormalization for SDs for step   5815
#
#
# Done with computing the SD overlap of step 5. Elapsed time 0.019858121871948242Done with computing the SD overlap of step 8. Elapsed time 0.02119612693786621
#
# Computing the SD overlaps for stepComputing the SD overlaps for step  1821
#
# Applying orthonormalization for SDs for step 12
# Applying orthonormalization for SDs for step 15Done with computing the SD overlap of step 12. Elapsed time 0.018316268920898438
#
# Computing the SD overlaps for step 13
# Done with computing the SD overlap of step 15. Elapsed time 0.017237186431884766
# Computing the SD overlaps for step 16
# Applying orthonormalization for SDs for step Applying orthonormalization for SDs for step18
# 21
# Done with computing the SD overlap of step 18. Elapsed time 0.01802539825439453
# Done with computing the SD overlap of step 21. Elapsed time 0.0183866024017334Computing the SD overlaps for step
#  19Computing the SD overlaps for step
#  22
# Applying orthonormalization for SDs for step 13
# Applying orthonormalization for SDs for step 16
# Done with computing the SD overlap of step 13. Elapsed time 0.017674684524536133
# Computing the SD overlaps for step Done with computing the SD overlap of step 16. Elapsed time 0.015731811523437514
#
# Computing the SD overlaps for step 17
# Applying orthonormalization for SDs for step 19
# Applying orthonormalization for SDs for step 22
# Done with computing the SD overlap of step 19. Elapsed time 0.016887664794921875
# Computing the SD overlaps for stepDone with computing the SD overlap of step 22. Elapsed time 0.01716017723083496
# 20Computing the SD overlaps for step
#  23
# Applying orthonormalization for SDs for step Applying orthonormalization for SDs for step14
#  17
# Done with computing the SD overlap of step 14. Elapsed time 0.016967058181762695
# Computing the SD overlaps for step 24
# Done with computing the SD overlap of step 17. Elapsed time 0.019687414169311523
# Computing the SD overlaps for stepApplying orthonormalization for SDs for step  2027
#
# Done with computing the SD overlap of step 20. Elapsed time 0.016875505447387695
# Computing the SD overlaps for step 30
# Applying orthonormalization for SDs for step 23
# Applying orthonormalization for SDs for step 24
# Done with computing the SD overlap of step 24. Elapsed time 0.017154932022094727
# Computing the SD overlaps for stepDone with computing the SD overlap of step 23. Elapsed time 0.03273272514343262
# 25
# Computing the SD overlaps for step Applying orthonormalization for SDs for step33Applying orthonormalization for SDs for step
# 3027
#
# Done with computing the SD overlap of step 30. Elapsed time 0.017019033432006836
# Done with computing the SD overlap of step 27. Elapsed time 0.022561311721801758Computing the SD overlaps for step
#  31Computing the SD overlaps for step
#  28
# Applying orthonormalization for SDs for step 25
# Done with computing the SD overlap of step 25. Elapsed time 0.016805410385131836
# Computing the SD overlaps for step 26
# Applying orthonormalization for SDs for step 31
# Applying orthonormalization for SDs for step Applying orthonormalization for SDs for step33
# Done with computing the SD overlap of step 31. Elapsed time 0.01669573783874511728
#
# Computing the SD overlaps for step 32
# Done with computing the SD overlap of step 28. Elapsed time 0.019104719161987305
# Done with computing the SD overlap of step 33. Elapsed time 0.026364803314208984Computing the SD overlaps for step
# Applying orthonormalization for SDs for step  29Computing the SD overlaps for step26
#
# 34
# Done with computing the SD overlap of step 26. Elapsed time 0.017073631286621094
# Computing the SD overlaps for step 36
# Applying orthonormalization for SDs for step 32
# Done with computing the SD overlap of step 32. Elapsed time 0.016603708267211914
# Applying orthonormalization for SDs for stepComputing the SD overlaps for step  3929
#
# Applying orthonormalization for SDs for stepDone with computing the SD overlap of step 29. Elapsed time 0.017525196075439453Applying orthonormalization for SDs for step
# 34
# Computing the SD overlaps for step36
# 42
# Done with computing the SD overlap of step 34. Elapsed time 0.02110004425048828
# Computing the SD overlaps for stepDone with computing the SD overlap of step 36. Elapsed time 0.01918339729309082
# 35
# Computing the SD overlaps for step Applying orthonormalization for SDs for step37 39
#
# Done with computing the SD overlap of step 39. Elapsed time 0.016505956649780273
# Computing the SD overlaps for step 40Applying orthonormalization for SDs for step
#  42
# Done with computing the SD overlap of step 42. Elapsed time 0.01609969139099121
# Computing the SD overlaps for step 43
# Applying orthonormalization for SDs for step 35
# Applying orthonormalization for SDs for step Done with computing the SD overlap of step 35. Elapsed time 0.01791501045227050837
#
# Applying orthonormalization for SDs for step Computing the SD overlaps for step40
# 45
# Done with computing the SD overlap of step 37. Elapsed time 0.02064824104309082
# Done with computing the SD overlap of step 40. Elapsed time 0.016440629959106445Computing the SD overlaps for step
#  Applying orthonormalization for SDs for stepComputing the SD overlaps for step38  43
#
# 41
# Done with computing the SD overlap of step 43. Elapsed time 0.015622138977050781
# Computing the SD overlaps for step 44
# Applying orthonormalization for SDs for step 45
# Done with computing the SD overlap of step 45. Elapsed time 0.016768455505371094
# Applying orthonormalization for SDs for step Computing the SD overlaps for step41Applying orthonormalization for SDs for step
#   46
# 38
# Applying orthonormalization for SDs for step 44
# Done with computing the SD overlap of step 41. Elapsed time 0.016875743865966797
# Done with computing the SD overlap of step 38. Elapsed time 0.01824045181274414
# Done with computing the SD overlap of step 44. Elapsed time 0.015289068222045898
# Applying orthonormalization for SDs for step 46
# Done with computing the SD overlap of step 46. Elapsed time 0.015776395797729492
# Done with computing the SD overlaps. Elapsed time: 0.6432671546936035
# Applying state-reordering to SDs overlaps...
#
# Done with state-reordering of SDs. Elapsed time: 0.1697216033935547
# Applying state-reordering to St_ci...
#
# Done with state-reordering to St_cis. Elapsed time: 1.4700727462768555

# %% [markdown]
# ## 4. Plotting the results <a name='plotting'></a>
# [Back to TOC](#toc)
#
# ### 4.1. NAC distribution <a name='nac_dist'></a>
#
# One of the intuitive ways to visualize the NACs is to plot the distribution of the NACs. Here we plot them for SP and MB excited states.

# %%
# %matplotlib notebook

for basis in ['sd','ci']:
    nac = []
    nac_files = glob.glob(F'res-mb-sd/Hvib_{basis}*im*')
    for nac_file in nac_files:
        hvib = sp.load_npz(nac_file)
        hvib_dense = hvib.todense().real
        for i in range(hvib.shape[0]):
            for j in range(hvib.shape[0]):
                if j != i:
                    nac_ij = np.abs(hvib_dense[i,j])* 1000.0 * units.au2ev
                    x_mb = MATRIX(1,1)
                    x_mb.set(0, 0, nac_ij )
                    nac.append( x_mb )
    bin_supp, dens, cum = data_stat.cmat_distrib( nac, 0, 0, 0, 0, 50, 0.1)
    plt.plot( bin_supp, dens, label=basis)
plt.xlabel('|NAC|, meV')
plt.ylabel('PD, 1/meV')
plt.title('NAC distribution, SP vs MB')
plt.legend()
plt.tight_layout()
# plt.savefig('nac_dist_1.jpg', dpi=600)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 4.2. Energy vs time <a name='ene_time'></a>
# Here, we plot the excited states energy vs time. Since the excited states were sorted by their `'identity'` it is easy to visualize the states energies crossings.

# %%
# %matplotlib notebook
titles = ['SP basis', 'MB basis']
plt.figure()
for c, basis in enumerate(['sd','ci']):
    plt.subplot(1,2,c+1)
    energy_files = glob.glob(F'res-mb-sd/Hvib_{basis}*re*')
    energy_files = data_io.sort_hvib_file_names(energy_files)
    print('Sorted energy files are:', energy_files)
    dt = 1.0 # fs
    energies = []
    for file in energy_files:
        energies.append(np.diag(sp.load_npz(file).todense().real))
    energies = np.array(energies)*units.au2ev
    md_time = np.arange(0,energies.shape[0]*dt,dt)
    print(energies.shape)
    for i in range(energies.shape[1]):
        plt.plot(md_time, energies[:,i]-energies[:,0])
    
    plt.title(titles[c])
    plt.ylabel('Excitation energy, eV')
    plt.xlabel('Time, fs')
    plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
# Sorted energy files are: ['res-mb-sd/Hvib_sd_1_re.npz', 'res-mb-sd/Hvib_sd_2_re.npz', 'res-mb-sd/Hvib_sd_3_re.npz', 'res-mb-sd/Hvib_sd_4_re.npz', 'res-mb-sd/Hvib_sd_5_re.npz', 'res-mb-sd/Hvib_sd_6_re.npz', 'res-mb-sd/Hvib_sd_7_re.npz', 'res-mb-sd/Hvib_sd_8_re.npz', 'res-mb-sd/Hvib_sd_9_re.npz', 'res-mb-sd/Hvib_sd_10_re.npz', 'res-mb-sd/Hvib_sd_11_re.npz', 'res-mb-sd/Hvib_sd_12_re.npz', 'res-mb-sd/Hvib_sd_13_re.npz', 'res-mb-sd/Hvib_sd_14_re.npz', 'res-mb-sd/Hvib_sd_15_re.npz', 'res-mb-sd/Hvib_sd_16_re.npz', 'res-mb-sd/Hvib_sd_17_re.npz', 'res-mb-sd/Hvib_sd_18_re.npz', 'res-mb-sd/Hvib_sd_19_re.npz', 'res-mb-sd/Hvib_sd_20_re.npz', 'res-mb-sd/Hvib_sd_21_re.npz', 'res-mb-sd/Hvib_sd_22_re.npz', 'res-mb-sd/Hvib_sd_23_re.npz', 'res-mb-sd/Hvib_sd_24_re.npz', 'res-mb-sd/Hvib_sd_25_re.npz', 'res-mb-sd/Hvib_sd_26_re.npz', 'res-mb-sd/Hvib_sd_27_re.npz', 'res-mb-sd/Hvib_sd_28_re.npz', 'res-mb-sd/Hvib_sd_29_re.npz', 'res-mb-sd/Hvib_sd_30_re.npz', 'res-mb-sd/Hvib_sd_31_re.npz', 'res-mb-sd/Hvib_sd_32_re.npz', 'res-mb-sd/Hvib_sd_33_re.npz', 'res-mb-sd/Hvib_sd_34_re.npz', 'res-mb-sd/Hvib_sd_35_re.npz', 'res-mb-sd/Hvib_sd_36_re.npz', 'res-mb-sd/Hvib_sd_37_re.npz', 'res-mb-sd/Hvib_sd_38_re.npz', 'res-mb-sd/Hvib_sd_39_re.npz', 'res-mb-sd/Hvib_sd_40_re.npz', 'res-mb-sd/Hvib_sd_41_re.npz', 'res-mb-sd/Hvib_sd_42_re.npz', 'res-mb-sd/Hvib_sd_43_re.npz', 'res-mb-sd/Hvib_sd_44_re.npz', 'res-mb-sd/Hvib_sd_45_re.npz', 'res-mb-sd/Hvib_sd_46_re.npz', 'res-mb-sd/Hvib_sd_47_re.npz']
# (47, 17)
# Sorted energy files are: ['res-mb-sd/Hvib_ci_1_re.npz', 'res-mb-sd/Hvib_ci_2_re.npz', 'res-mb-sd/Hvib_ci_3_re.npz', 'res-mb-sd/Hvib_ci_4_re.npz', 'res-mb-sd/Hvib_ci_5_re.npz', 'res-mb-sd/Hvib_ci_6_re.npz', 'res-mb-sd/Hvib_ci_7_re.npz', 'res-mb-sd/Hvib_ci_8_re.npz', 'res-mb-sd/Hvib_ci_9_re.npz', 'res-mb-sd/Hvib_ci_10_re.npz', 'res-mb-sd/Hvib_ci_11_re.npz', 'res-mb-sd/Hvib_ci_12_re.npz', 'res-mb-sd/Hvib_ci_13_re.npz', 'res-mb-sd/Hvib_ci_14_re.npz', 'res-mb-sd/Hvib_ci_15_re.npz', 'res-mb-sd/Hvib_ci_16_re.npz', 'res-mb-sd/Hvib_ci_17_re.npz', 'res-mb-sd/Hvib_ci_18_re.npz', 'res-mb-sd/Hvib_ci_19_re.npz', 'res-mb-sd/Hvib_ci_20_re.npz', 'res-mb-sd/Hvib_ci_21_re.npz', 'res-mb-sd/Hvib_ci_22_re.npz', 'res-mb-sd/Hvib_ci_23_re.npz', 'res-mb-sd/Hvib_ci_24_re.npz', 'res-mb-sd/Hvib_ci_25_re.npz', 'res-mb-sd/Hvib_ci_26_re.npz', 'res-mb-sd/Hvib_ci_27_re.npz', 'res-mb-sd/Hvib_ci_28_re.npz', 'res-mb-sd/Hvib_ci_29_re.npz', 'res-mb-sd/Hvib_ci_30_re.npz', 'res-mb-sd/Hvib_ci_31_re.npz', 'res-mb-sd/Hvib_ci_32_re.npz', 'res-mb-sd/Hvib_ci_33_re.npz', 'res-mb-sd/Hvib_ci_34_re.npz', 'res-mb-sd/Hvib_ci_35_re.npz', 'res-mb-sd/Hvib_ci_36_re.npz', 'res-mb-sd/Hvib_ci_37_re.npz', 'res-mb-sd/Hvib_ci_38_re.npz', 'res-mb-sd/Hvib_ci_39_re.npz', 'res-mb-sd/Hvib_ci_40_re.npz', 'res-mb-sd/Hvib_ci_41_re.npz', 'res-mb-sd/Hvib_ci_42_re.npz', 'res-mb-sd/Hvib_ci_43_re.npz', 'res-mb-sd/Hvib_ci_44_re.npz', 'res-mb-sd/Hvib_ci_45_re.npz', 'res-mb-sd/Hvib_ci_46_re.npz']
# (46, 6)

# %% [markdown]
# ### 4.3. NAC map <a name='nac_map'></a>
# Another way of visualizing the NAC values is to plot the average NAC matrix using `plt.imshow`.

# %%
# %matplotlib notebook
plt.figure()
nac_files = glob.glob('res-mb-sd/Hvib_sd*im*')
for c, nac_file in enumerate(nac_files):
    nac_mat = sp.load_npz(nac_file).todense().real
    if c==0:
        nac_ave = np.zeros(nac_mat.shape)
    nac_ave += np.abs(nac_mat)
nac_ave *= 1000*units.au2ev/c
nstates = nac_ave.shape[0]
plt.imshow(np.flipud(nac_ave), cmap='hot', extent=(0,nstates,0,nstates))#, vmin=0, vmax=100)
plt.xlabel('State index')
plt.ylabel('State index')
plt.colorbar().ax.set_title('meV')
plt.title('SP NACs')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'SP NACs')

# %%
# %matplotlib notebook
nac_files = glob.glob('res-mb-sd/Hvib_ci*im*')
for c, nac_file in enumerate(nac_files):
    nac_mat = sp.load_npz(nac_file).todense().real
    if c==0:
        nac_ave = np.zeros(nac_mat.shape)
    nac_ave += np.abs(nac_mat)
nac_ave *= 1000*units.au2ev/c
nstates = nac_ave.shape[0]
plt.imshow(np.flipud(nac_ave), cmap='hot', extent=(0,nstates,0,nstates))#, vmin=0, vmax=100)
plt.xlabel('State index')
plt.ylabel('State index')
plt.colorbar().ax.set_title('meV')
plt.title('MB NACs')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'MB NACs')
