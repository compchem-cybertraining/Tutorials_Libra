# %% [markdown]
# # Machine-leaned Kohn-Sham Hamiltonian mapping for computation of the molecular orbital overlaps and time-overlaps
#
# In this tutorial, we use machine-learning to perform [step 2](../../../7_step2_cp2k) calculations.
# This approach uses Kohn-Sham Hamiltonian mapping approach where the atomic-guess Hamiltonians from a PBE calculations are
# directly mapped into B3LYP Hamiltonians. The molecular orbitals obtained from solving generalized Kohn-Sham equations
# are used to compute the overlaps and time-overlap matrices. One can then use these data for [step3](../../../8_step3) and
# [step4](../../../9_step4) calculations.
#
#
# ## Table of contents
# <a name="toc"></a>
# 1. [Importing needed libraries](#import)
#
#
# 2. [Overview of required files](#required_files)
#
#
# 3. [Training machine-learning model](#train_model)
#
#
# 4. [Using machine-learning model](#use_model)
#
#
# 5. [Plotting machine-learned energies](#plot_data)
#
#
# ### A. Learning objectives
#
# * To be able to compute molecular orbital overlap calculations on using machine-learning techniques
#
# ### B. Use cases
#
# * [Training machine-learning model](#train_model)
#
# * [Using machine-learning model](#use_model)
#
# * [Plotting machine-learned energies](#plot_data)
#
#
# ### C. Functions
#
# - `libra_py.workflows.nbra`
#   - `ml_map`
#     - [`train`](#train_model)
#     - [`load_models`](#use_model)
#     - [`compute_properties`](#use_model)

# %% [markdown]
# ## 1. Importing needed libraries <a name="import"></a>
# [Back to TOC](#toc)
#
# Import `train`, `load_models`, and `compute_properties` function from `ml_map` module using the following commands:

# %%
import os
import numpy as np
import scipy.sparse as sp
import matplotlib.pyplot as plt
from libra_py import units
from libra_py.workflows.nbra.ml_map import train, load_models, compute_properties

# %% [markdown]
# ## 2. Overview of required files <a name="required_files"></a>
# [Back to TOC](#toc)
#
# To train the machine-learning model, one requires a set of inputs and outputs. These inputs and outputs
# were already obtained in the [previous step](../1_generate_data). The inputs are atomic-guess PBE Hamiltonians
# and the outputs are converged B3LYP Hamiltonians obtained for a couple of randomly selected geometries of a precomputed
# trajectory. The input data are stored with a prefix and a property and the output data have an extra `_ref_` in their names.

# %% [markdown]
# # 3. Training machine-learning model <a name="train_model"></a>
# [Back to TOC](#toc)
#
# Here are the set of parameters required to train a machine-learning model using `train` function in `ml_map` module.
#
#
# `prefix`: The prefix used to save the files.
#
# `path_to_input_mats`: The full path to input matrices files.
#
# `path_to_output_mats`: The full path to output matrices files.
#
# `path_to_trajectory_xyz_file`: The full path to trajectory `xyz` file. This is required for computation of the overlap
# matrix and solving generalized Kohn-Sham equations. Also, it will be required for computation of the molecular orbitals
# overlap and time-overlap matrices.
#
# `path_to_sample_files`: The full path to sample files obtained in the [generate data step](../1_generate_data).
#
# `input_property`: The input property which appears in the middle of the name of the input files. It can take values of `kohn_sham`, `density`, `overlap`, and `hamiltonian` for xTB calculations.
#
# `output_property`: The output property which appears in the middle of the name of the output files. It can take values of `kohn_sham`, `density`, `overlap`, and `hamiltonian` for xTB calculations.
#
# We use a kernel ridge regression (KRR) method for mapping the Hamiltonian matrix from one calculations to another. The parameters for setting up the KRR are as follows:
#
# `kernel`: The kernel name: `linear`, `poly` for polynomial kernels, and `rbf` for radial basis function kernel.
#
# `degree`: The degree of the kernel function in case of a `poly` kernel.
#
# `alpha`: This parameter represents the regularization strength in ridge regression. It controls the complexity of the model: a higher alpha value increases the amount of regularization, which in turn reduces the model's variance but might increase its bias. Specifically, it multiplies the identity matrix that is added to the kernel matrix in the ridge regression formula. This parameter helps to prevent overfitting by ensuring that the coefficients do not grow too large.
#
#
# `gamma`: This parameter is specific to certain types of kernels such as the radial basis function, sigmoid, or polynomial kernels. Gamma defines how much influence a single training input has. The larger the gamma, the closer other inputs must be to be affected.
#
# `scaler`: The scaler to scale the input and data. It can take `standard_scaler` and `minmax_scaler` values. The `standard_scaler` is recommended.
#
# `save_models`: A boolean flag for saving the trained model
#
# `path_to_save_models`: The full path to save the model
#
# `save_ml_ham`: A boolean flag for saving the predicted Hamiltonian matrices
#
# `save_ao_overlap`: A boolean flag for saving the atomic orbital overlap matrices
#
# `save_ml_mos`: A boolean flag for saving the molecular orbitals eigenvalues and eigenvectors
#
#
# `partitioning_method`: The partitioning of the Hamiltonian matrix. It can take values of `equal` and `atomic`. In the
# `equal` partitioning, the upper triangular part of the Hamiltonian matrix is partitioned into `npartition` equal segments.
# A separate model maps each input partition to its corresponding partition in the output matrix.\
# The `atomic` partitioning method partitions the matrix based on the atomic angular momentum components of the matrix for each
# basis set.
#
# `npartition`: The number of partition in the `equal` partitioning method.
#
# `memory_efficient`: A boolean flag for memory efficiency of the calculations. This will remove the raw data and will remove them
# from the memory after they are processed.
#
# `nprocs`: The number of processors for computing the overlap matrices.
#
# `write_wfn_file`: A boolean flag for writing `wfn` files readable by CP2K.
#
# `path_to_save_wfn_files`: The full path to save the `wfn` files.
#
# `is_periodic`: The flag for periodicity of he system for computing the overlaps.
#
# `A_cell_vector`: A list containing the A cell vector.
#
# `B_cell_vector`: A list containing the B cell vector.
#
# `C_cell_vector`: A list containing the C cell vector.
#
# `periodicity_type`: The periodicity type for each direction of the periodic cell.
#
# `lowest_orbital`: The lowest orbital index to be saved.
#
# `highest_orbital`: The highest orbital index to be saved.
#
# `res_dir`: The full path to save the overlap, time-overlap, and energies similar as in [step 2](../../../7_step2_cp2k).
#
# `train_parallel`: A boolean flag for training models in parallel.

# %%
params = { # Part 1
    "prefix": "c60",
    "path_to_input_mats": os.getcwd() + "/../1_generate_data/guess",
    "path_to_output_mats": os.getcwd() + "/../1_generate_data/ref",
    "path_to_trajectory_xyz_file": os.getcwd() + "/../1_generate_data/C60-pos-1.xyz",
    "path_to_sample_files": os.getcwd() + "/../1_generate_data/sample_files",
    "input_property":  "kohn_sham",
    "output_property": "kohn_sham",
    # Part 2 
    "kernel":"linear",
    "degree": 1,
    "alpha": 0.02,
    "gamma": 0.02,
    "scaler": "standard_scaler", # "minmax_scaler"
    "save_models": True,
    # The next savings are only for 
    # development purposes so it's recommended to turn them off
    # since they will occupy a huge amount of disk space
    "save_ml_ham": False,
    "save_ao_overlap": False,
    "save_ml_mos": False,
    "path_to_save_models": os.getcwd() + "/models",
    "partitioning_method": "equal", # Optios: "equal" and "atomic"
    "npartition": 60,
    "memory_efficient": True,
    "train_parallel": False,
    # Part 3
    "compute_overlap": True,
    "nprocs": 8,
    "write_wfn_file": True,
    "path_to_save_wfn_files": os.getcwd() + "/wfn_files",
    "istep": 0,
    "is_periodic": False,
    "A_cell_vector": [10.0, 0.0, 0.0],
    "B_cell_vector": [0.0, 10.0, 0.0],
    "C_cell_vector": [0.0, 0.0, 10.0],
    "periodicity_type": "XYZ",
    "lowest_orbital": 100,
    "highest_orbital": 140,
    "res_dir": os.getcwd() + "/res"}

models, models_error, input_scalers, output_scalers = train(params)
# Out:
# Training R^2: 0.9999998307113434
# Training MSE: 7.628980443753991e-13   MAE: 2.1310102402240974e-07
# ===========================================
# Training R^2: 0.9999995669986604
# Training MSE: 6.682178316234825e-13   MAE: 2.0641800169632275e-07
# ===========================================
# Training R^2: 0.9999999127701016
# Training MSE: 7.524487847719702e-13   MAE: 2.0914870104186396e-07
# ===========================================
# Training R^2: 0.999999564475302
# Training MSE: 4.780142442502884e-13   MAE: 1.577124777407067e-07
# ===========================================
# Training R^2: 0.9999998971693181
# Training MSE: 5.766012497106645e-13   MAE: 1.7374234196768328e-07
# ===========================================
# Training R^2: 0.9999996250503733
# Training MSE: 7.214455751283025e-13   MAE: 1.7657013819051605e-07
# ===========================================
# Training R^2: 0.9999997538100934
# Training MSE: 8.774782538680085e-13   MAE: 1.9626980723732602e-07
# ===========================================
# Training R^2: 0.9999997609014332
# Training MSE: 8.179127919023132e-13   MAE: 1.9304698635682104e-07
# ===========================================
# Training R^2: 0.9999997298013492
# Training MSE: 1.1324505238324741e-12   MAE: 2.1345085534480295e-07
# ===========================================
# Training R^2: 0.9999998377356705
# Training MSE: 5.833688292604902e-13   MAE: 1.5970517396240485e-07
# ===========================================
# Training R^2: 0.9999996637530456
# Training MSE: 6.943855235773811e-13   MAE: 1.9680614352699943e-07
# ===========================================
# Training R^2: 0.999999713162355
# Training MSE: 6.61773708813051e-13   MAE: 1.5385946142898109e-07
# ===========================================
# Training R^2: 0.9999994829369849
# Training MSE: 5.682076647780699e-13   MAE: 1.5747096414430397e-07
# ===========================================
# Training R^2: 0.9999997560263167
# Training MSE: 8.451339244361939e-13   MAE: 1.6392613841985764e-07
# ===========================================
# Training R^2: 0.999999527803308
# Training MSE: 1.900209893762097e-12   MAE: 2.9923247814652945e-07
# ===========================================
# Training R^2: 0.9999997510330746
# Training MSE: 7.628264333021956e-13   MAE: 1.996782449949263e-07
# ===========================================
# Training R^2: 0.9999996995085405
# Training MSE: 6.50872811251654e-13   MAE: 1.6961936978051325e-07
# ===========================================
# Training R^2: 0.9999994148357038
# Training MSE: 1.0566152258071286e-12   MAE: 2.428234822476017e-07
# ===========================================
# Training R^2: 0.9999998631692609
# Training MSE: 5.581448911206701e-13   MAE: 1.406826856506907e-07
# ===========================================
# Training R^2: 0.9999996972092582
# Training MSE: 1.2345837548584479e-12   MAE: 2.1609946876906572e-07
# ===========================================
# Training R^2: 0.999999659037582
# Training MSE: 4.630641083963249e-13   MAE: 1.0052988523274143e-07
# ===========================================
# Training R^2: 0.9999996798722609
# Training MSE: 4.843442972322406e-13   MAE: 1.221079029325753e-07
# ===========================================
# Training R^2: 0.9999993390647901
# Training MSE: 4.1626734223770844e-13   MAE: 1.0568086244741014e-07
# ===========================================
# Training R^2: 0.9999996851551491
# Training MSE: 8.246516013449809e-13   MAE: 1.8372188750087043e-07
# ===========================================
# Training R^2: 0.9999997981486236
# Training MSE: 6.44325632120838e-13   MAE: 1.391319232673257e-07
# ===========================================
# Training R^2: 0.9999995432782192
# Training MSE: 1.1432000515569587e-12   MAE: 1.9333406467375195e-07
# ===========================================
# Training R^2: 0.9999995255288608
# Training MSE: 5.940418990956262e-13   MAE: 1.5427127701702472e-07
# ===========================================
# Training R^2: 0.999999692471635
# Training MSE: 5.95053969274478e-13   MAE: 1.704677600843388e-07
# ===========================================
# Training R^2: 0.9999998042662305
# Training MSE: 8.183383226522722e-13   MAE: 2.5522240683265935e-07
# ===========================================
# Training R^2: 0.999999744922447
# Training MSE: 9.634472129778138e-13   MAE: 2.365598015991411e-07
# ===========================================
# Training R^2: 0.9999995102120405
# Training MSE: 7.788566940258383e-13   MAE: 1.7911949438746664e-07
# ===========================================
# Training R^2: 0.9999996185710968
# Training MSE: 1.412409793691719e-12   MAE: 2.08306345374143e-07
# ===========================================
# Training R^2: 0.9999995610753678
# Training MSE: 1.0151844725228704e-12   MAE: 1.5467891395302438e-07
# ===========================================
# Training R^2: 0.999999543284551
# Training MSE: 7.91916713485993e-13   MAE: 1.4907878671299623e-07
# ===========================================
# Training R^2: 0.9999995484565396
# Training MSE: 1.0227899460864648e-12   MAE: 2.0394572899377348e-07
# ===========================================
# Training R^2: 0.9999996495186066
# Training MSE: 1.2252131769201465e-12   MAE: 2.3670865153478215e-07
# ===========================================
# Training R^2: 0.9999996395677596
# Training MSE: 1.2062185601442515e-12   MAE: 2.54850432347639e-07
# ===========================================
# Training R^2: 0.9999997501754502
# Training MSE: 1.1164982666262365e-12   MAE: 2.242733897459908e-07
# ===========================================
# Training R^2: 0.999999596289871
# Training MSE: 1.3625849179268562e-12   MAE: 2.8551318679241466e-07
# ===========================================
# Training R^2: 0.9999997595197762
# Training MSE: 1.0980231206395834e-12   MAE: 2.71894541064052e-07
# ===========================================
# Training R^2: 0.999999633875684
# Training MSE: 1.1409876187575505e-12   MAE: 2.3761791162635167e-07
# ===========================================
# Training R^2: 0.999999661115449
# Training MSE: 1.1207978328579365e-12   MAE: 1.9076276035364036e-07
# ===========================================
# Training R^2: 0.9999994034353111
# Training MSE: 1.6930397233968536e-12   MAE: 2.3110333062667177e-07
# ===========================================
# Training R^2: 0.9999997352427425
# Training MSE: 2.2796547990849737e-12   MAE: 3.041775252268132e-07
# ===========================================
# Training R^2: 0.999999708311424
# Training MSE: 1.2824947529276943e-12   MAE: 2.907372752467562e-07
# ===========================================
# Training R^2: 0.9999995803225282
# Training MSE: 1.3430773407761256e-12   MAE: 2.961981049486799e-07
# ===========================================
# Training R^2: 0.9999998440623177
# Training MSE: 1.6185968245382472e-12   MAE: 2.809419715082794e-07
# ===========================================
# Training R^2: 0.9999995655613156
# Training MSE: 1.2609319766961545e-12   MAE: 2.2749204882097694e-07
# ===========================================
# Training R^2: 0.9999993155546562
# Training MSE: 9.57219086601874e-13   MAE: 2.1571745972694471e-07
# ===========================================
# Training R^2: 0.9999993304358658
# Training MSE: 1.067947764043307e-12   MAE: 1.839887414835168e-07
# ===========================================
# Training R^2: 0.9999994324680371
# Training MSE: 1.0106896934481074e-12   MAE: 2.2210545161382396e-07
# ===========================================
# Training R^2: 0.9999993259319157
# Training MSE: 1.2875141957594067e-12   MAE: 2.3588429310993516e-07
# ===========================================
# Training R^2: 0.9999996451838802
# Training MSE: 1.2922407862412577e-12   MAE: 3.17232762981675e-07
# ===========================================
# Training R^2: 0.9999998735634309
# Training MSE: 1.5256971650975788e-12   MAE: 3.855414208876562e-07
# ===========================================
# Training R^2: 0.99999979405455
# Training MSE: 1.0923506002300635e-12   MAE: 2.780271197755981e-07
# ===========================================
# Training R^2: 0.999999944360932
# Training MSE: 1.465238089900768e-12   MAE: 4.170452547592131e-07
# ===========================================
# Training R^2: 0.999999846534934
# Training MSE: 1.2918383307583865e-12   MAE: 2.619411755382604e-07
# ===========================================
# Training R^2: 0.9999999400847869
# Training MSE: 1.5968242510908984e-12   MAE: 4.236848197503405e-07
# ===========================================
# Training R^2: 0.9999999287155313
# Training MSE: 1.8319441551794544e-12   MAE: 4.113433996542794e-07
# ===========================================
# Training R^2: 0.9999999390690043
# Training MSE: 2.803860994808128e-12   MAE: 6.185694720067218e-07
# ===========================================
# Average MAE for all models: 2.283145581135097e-07
# Average MSE for all models: 1.0540494340264043e-12
# Average R^2 for all models: 0.9999996690860441
# Done with training!!
# mkdir: cannot create directory ‘/projects/academic/alexeyak/mohammad/my_repositories/Tutorials_Libra/6_dynamics/2_nbra_workflows/16_ml_hamiltonian_mapping/1_c60/2_ml_step2/models’: File exists

# %% [markdown]
# # 4. Using machine-learning model <a name="use_model"></a>
# [Back to TOC](#toc)
#
# Here, we use the trained models to compute the properties such as the molecular orbitals with their overlap and time-overlaps.
# One can either load the models using `load_models` function, in case of `"save_models": True` or they can reuse the `models` and other variables from output by `train` function.
#
# The `load_models` take two positional arguments:
#
# * The full path to saved models.
# * The dictionary defined above.
#
# After the models are trained or loaded, one can use `compute_properties` function to predict the molecular orbitals and
# their properties. This function will compute the properties for all guess input data in guess directory, the `params["path_to_input_mats"]`.

# %% [markdown]
# This is how you can load models:

# %%
# You can also reload the saved models that are already trained with input and output data
models, models_error, input_scalers, output_scalers = load_models(os.getcwd()+'/models', params)
# Out:
# Loading models...
# Done with loading models!...

# %% [markdown]
# Now, we can use them:

# %%
compute_properties(params, models, input_scalers, output_scalers)
# Out:
# mkdir: cannot create directory ‘/projects/academic/alexeyak/mohammad/my_repositories/Tutorials_Libra/6_dynamics/2_nbra_workflows/16_ml_hamiltonian_mapping/1_c60/2_ml_step2/wfn_files’: File exists
# mkdir: cannot create directory ‘/projects/academic/alexeyak/mohammad/my_repositories/Tutorials_Libra/6_dynamics/2_nbra_workflows/16_ml_hamiltonian_mapping/1_c60/2_ml_step2/res’: File exists
# ========================
#  Performing calculations for step  1000
# ========================
#  Performing calculations for step  1001
# ========================
#  Performing calculations for step  1002
# ========================
#  Performing calculations for step  1003
# ========================
#  Performing calculations for step  1004
# ========================
#  Performing calculations for step  1005
# ========================
#  Performing calculations for step  1006
# ========================
#  Performing calculations for step  1007
# ========================
#  Performing calculations for step  1008
# ========================
#  Performing calculations for step  1009
# ========================
#  Performing calculations for step  1010
# ========================
#  Performing calculations for step  1011
# ========================
#  Performing calculations for step  1012
# ========================
#  Performing calculations for step  1013
# ========================
#  Performing calculations for step  1014
# ========================
#  Performing calculations for step  1015
# ========================
#  Performing calculations for step  1016
# ========================
#  Performing calculations for step  1017
# ========================
#  Performing calculations for step  1018
# ========================
#  Performing calculations for step  1019
# ========================
#  Performing calculations for step  1020
# ========================
#  Performing calculations for step  1021
# ========================
#  Performing calculations for step  1022
# ========================
#  Performing calculations for step  1023
# ========================
#  Performing calculations for step  1024
# ========================
#  Performing calculations for step  1025
# ========================
#  Performing calculations for step  1026
# ========================
#  Performing calculations for step  1027
# ========================
#  Performing calculations for step  1028
# ========================
#  Performing calculations for step  1029
# ========================
#  Performing calculations for step  1030
# ========================
#  Performing calculations for step  1031
# ========================
#  Performing calculations for step  1032
# ========================
#  Performing calculations for step  1033
# ========================
#  Performing calculations for step  1034
# ========================
#  Performing calculations for step  1035
# ========================
#  Performing calculations for step  1036
# ========================
#  Performing calculations for step  1037
# ========================
#  Performing calculations for step  1038
# ========================
#  Performing calculations for step  1039
# ========================
#  Performing calculations for step  1040
# ========================
#  Performing calculations for step  1041
# ========================
#  Performing calculations for step  1042
# ========================
#  Performing calculations for step  1043
# ========================
#  Performing calculations for step  1044
# ========================
#  Performing calculations for step  1045
# ========================
#  Performing calculations for step  1046
# ========================
#  Performing calculations for step  1047
# ========================
#  Performing calculations for step  1048
# ========================
#  Performing calculations for step  1049
# ========================
#  Performing calculations for step  1050
# ========================
#  Performing calculations for step  1051
# ========================
#  Performing calculations for step  1052
# ========================
#  Performing calculations for step  1053
# ========================
#  Performing calculations for step  1054
# ========================
#  Performing calculations for step  1055
# ========================
#  Performing calculations for step  1056
# ========================
#  Performing calculations for step  1057
# ========================
#  Performing calculations for step  1058
# ========================
#  Performing calculations for step  1059
# ========================
#  Performing calculations for step  1060
# ========================
#  Performing calculations for step  1061
# ========================
#  Performing calculations for step  1062
# ========================
#  Performing calculations for step  1063
# ========================
#  Performing calculations for step  1064
# ========================
#  Performing calculations for step  1065
# ========================
#  Performing calculations for step  1066
# ========================
#  Performing calculations for step  1067
# ========================
#  Performing calculations for step  1068
# ========================
#  Performing calculations for step  1069
# ========================
#  Performing calculations for step  1070
# ========================
#  Performing calculations for step  1071
# ========================
#  Performing calculations for step  1072
# ========================
#  Performing calculations for step  1073
# ========================
#  Performing calculations for step  1074
# ========================
#  Performing calculations for step  1075
# ========================
#  Performing calculations for step  1076
# ========================
#  Performing calculations for step  1077
# ========================
#  Performing calculations for step  1078
# ========================
#  Performing calculations for step  1079
# ========================
#  Performing calculations for step  1080
# ========================
#  Performing calculations for step  1081
# ========================
#  Performing calculations for step  1082
# ========================
#  Performing calculations for step  1083
# ========================
#  Performing calculations for step  1084
# ========================
#  Performing calculations for step  1085
# ========================
#  Performing calculations for step  1086
# ========================
#  Performing calculations for step  1087
# ========================
#  Performing calculations for step  1088
# ========================
#  Performing calculations for step  1089
# ========================
#  Performing calculations for step  1090
# ========================
#  Performing calculations for step  1091
# ========================
#  Performing calculations for step  1092
# ========================
#  Performing calculations for step  1093
# ========================
#  Performing calculations for step  1094
# ========================
#  Performing calculations for step  1095
# ========================
#  Performing calculations for step  1096
# ========================
#  Performing calculations for step  1097
# ========================
#  Performing calculations for step  1098
# ========================
#  Performing calculations for step  1099
# ========================
#  Performing calculations for step  1100
# ========================
#  Performing calculations for step  1101
# ========================
#  Performing calculations for step  1102
# ========================
#  Performing calculations for step  1103
# ========================
#  Performing calculations for step  1104
# ========================
#  Performing calculations for step  1105
# ========================
#  Performing calculations for step  1106
# ========================
#  Performing calculations for step  1107
# ========================
#  Performing calculations for step  1108
# ========================
#  Performing calculations for step  1109
# ========================
#  Performing calculations for step  1110
# ========================
#  Performing calculations for step  1111
# ========================
#  Performing calculations for step  1112
# ========================
#  Performing calculations for step  1113
# ========================
#  Performing calculations for step  1114
# ========================
#  Performing calculations for step  1115
# ========================
#  Performing calculations for step  1116
# ========================
#  Performing calculations for step  1117
# ========================
#  Performing calculations for step  1118
# ========================
#  Performing calculations for step  1119
# ========================
#  Performing calculations for step  1120
# ========================
#  Performing calculations for step  1121
# ========================
#  Performing calculations for step  1122
# ========================
#  Performing calculations for step  1123
# ========================
#  Performing calculations for step  1124
# ========================
#  Performing calculations for step  1125
# ========================
#  Performing calculations for step  1126
# ========================
#  Performing calculations for step  1127
# ========================
#  Performing calculations for step  1128
# ========================
#  Performing calculations for step  1129
# ========================
#  Performing calculations for step  1130
# ========================
#  Performing calculations for step  1131
# ========================
#  Performing calculations for step  1132
# ========================
#  Performing calculations for step  1133
# ========================
#  Performing calculations for step  1134
# ========================
#  Performing calculations for step  1135
# ========================
#  Performing calculations for step  1136
# ========================
#  Performing calculations for step  1137
# ========================
#  Performing calculations for step  1138
# ========================
#  Performing calculations for step  1139
# ========================
#  Performing calculations for step  1140
# ========================
#  Performing calculations for step  1141
# ========================
#  Performing calculations for step  1142
# ========================
#  Performing calculations for step  1143
# ========================
#  Performing calculations for step  1144
# ========================
#  Performing calculations for step  1145
# ========================
#  Performing calculations for step  1146
# ========================
#  Performing calculations for step  1147
# ========================
#  Performing calculations for step  1148
# ========================
#  Performing calculations for step  1149
# ========================
#  Performing calculations for step  1150
# ========================
#  Performing calculations for step  1151
# ========================
#  Performing calculations for step  1152
# ========================
#  Performing calculations for step  1153
# ========================
#  Performing calculations for step  1154
# ========================
#  Performing calculations for step  1155
# ========================
#  Performing calculations for step  1156
# ========================
#  Performing calculations for step  1157
# ========================
#  Performing calculations for step  1158
# ========================
#  Performing calculations for step  1159
# ========================
#  Performing calculations for step  1160
# ========================
#  Performing calculations for step  1161
# ========================
#  Performing calculations for step  1162
# ========================
#  Performing calculations for step  1163
# ========================
#  Performing calculations for step  1164
# ========================
#  Performing calculations for step  1165
# ========================
#  Performing calculations for step  1166
# ========================
#  Performing calculations for step  1167
# ========================
#  Performing calculations for step  1168
# ========================
#  Performing calculations for step  1169
# ========================
#  Performing calculations for step  1170
# ========================
#  Performing calculations for step  1171
# ========================
#  Performing calculations for step  1172
# ========================
#  Performing calculations for step  1173
# ========================
#  Performing calculations for step  1174
# ========================
#  Performing calculations for step  1175
# ========================
#  Performing calculations for step  1176
# ========================
#  Performing calculations for step  1177
# ========================
#  Performing calculations for step  1178
# ========================
#  Performing calculations for step  1179
# ========================
#  Performing calculations for step  1180
# ========================
#  Performing calculations for step  1181
# ========================
#  Performing calculations for step  1182
# ========================
#  Performing calculations for step  1183
# ========================
#  Performing calculations for step  1184
# ========================
#  Performing calculations for step  1185
# ========================
#  Performing calculations for step  1186
# ========================
#  Performing calculations for step  1187
# ========================
#  Performing calculations for step  1188
# ========================
#  Performing calculations for step  1189
# ========================
#  Performing calculations for step  1190
# ========================
#  Performing calculations for step  1191
# ========================
#  Performing calculations for step  1192
# ========================
#  Performing calculations for step  1193
# ========================
#  Performing calculations for step  1194
# ========================
#  Performing calculations for step  1195
# ========================
#  Performing calculations for step  1196
# ========================
#  Performing calculations for step  1197
# ========================
#  Performing calculations for step  1198
# ========================
#  Performing calculations for step  1199
# ========================
#  Performing calculations for step  1200
# ========================
#  Performing calculations for step  1201
# ========================
#  Performing calculations for step  1202
# ========================
#  Performing calculations for step  1203
# ========================
#  Performing calculations for step  1204
# ========================
#  Performing calculations for step  1205
# ========================
#  Performing calculations for step  1206
# ========================
#  Performing calculations for step  1207
# ========================
#  Performing calculations for step  1208
# ========================
#  Performing calculations for step  1209
# ========================
#  Performing calculations for step  1210
# ========================
#  Performing calculations for step  1211
# ========================
#  Performing calculations for step  1212
# ========================
#  Performing calculations for step  1213
# ========================
#  Performing calculations for step  1214
# ========================
#  Performing calculations for step  1215
# ========================
#  Performing calculations for step  1216
# ========================
#  Performing calculations for step  1217
# ========================
#  Performing calculations for step  1218
# ========================
#  Performing calculations for step  1219
# ========================
#  Performing calculations for step  1220
# ========================
#  Performing calculations for step  1221
# ========================
#  Performing calculations for step  1222
# ========================
#  Performing calculations for step  1223
# ========================
#  Performing calculations for step  1224
# ========================
#  Performing calculations for step  1225
# ========================
#  Performing calculations for step  1226
# ========================
#  Performing calculations for step  1227
# ========================
#  Performing calculations for step  1228
# ========================
#  Performing calculations for step  1229
# ========================
#  Performing calculations for step  1230
# ========================
#  Performing calculations for step  1231
# ========================
#  Performing calculations for step  1232
# ========================
#  Performing calculations for step  1233
# ========================
#  Performing calculations for step  1234
# ========================
#  Performing calculations for step  1235
# ========================
#  Performing calculations for step  1236
# ========================
#  Performing calculations for step  1237
# ========================
#  Performing calculations for step  1238
# ========================
#  Performing calculations for step  1239
# ========================
#  Performing calculations for step  1240
# ========================
#  Performing calculations for step  1241
# ========================
#  Performing calculations for step  1242
# ========================
#  Performing calculations for step  1243
# ========================
#  Performing calculations for step  1244
# ========================
#  Performing calculations for step  1245
# ========================
#  Performing calculations for step  1246
# ========================
#  Performing calculations for step  1247
# ========================
#  Performing calculations for step  1248
# ========================
#  Performing calculations for step  1249
# ========================
#  Performing calculations for step  1250
# ========================
#  Performing calculations for step  1251
# ========================
#  Performing calculations for step  1252
# ========================
#  Performing calculations for step  1253
# ========================
#  Performing calculations for step  1254
# ========================
#  Performing calculations for step  1255
# ========================
#  Performing calculations for step  1256
# ========================
#  Performing calculations for step  1257
# ========================
#  Performing calculations for step  1258
# ========================
#  Performing calculations for step  1259
# ========================
#  Performing calculations for step  1260
# ========================
#  Performing calculations for step  1261
# ========================
#  Performing calculations for step  1262
# ========================
#  Performing calculations for step  1263
# ========================
#  Performing calculations for step  1264
# ========================
#  Performing calculations for step  1265
# ========================
#  Performing calculations for step  1266
# ========================
#  Performing calculations for step  1267
# ========================
#  Performing calculations for step  1268
# ========================
#  Performing calculations for step  1269
# ========================
#  Performing calculations for step  1270
# ========================
#  Performing calculations for step  1271
# ========================
#  Performing calculations for step  1272
# ========================
#  Performing calculations for step  1273
# ========================
#  Performing calculations for step  1274
# ========================
#  Performing calculations for step  1275
# ========================
#  Performing calculations for step  1276
# ========================
#  Performing calculations for step  1277
# ========================
#  Performing calculations for step  1278
# ========================
#  Performing calculations for step  1279
# ========================
#  Performing calculations for step  1280
# ========================
#  Performing calculations for step  1281
# ========================
#  Performing calculations for step  1282
# ========================
#  Performing calculations for step  1283
# ========================
#  Performing calculations for step  1284
# ========================
#  Performing calculations for step  1285
# ========================
#  Performing calculations for step  1286
# ========================
#  Performing calculations for step  1287
# ========================
#  Performing calculations for step  1288
# ========================
#  Performing calculations for step  1289
# ========================
#  Performing calculations for step  1290
# ========================
#  Performing calculations for step  1291
# ========================
#  Performing calculations for step  1292
# ========================
#  Performing calculations for step  1293
# ========================
#  Performing calculations for step  1294
# ========================
#  Performing calculations for step  1295
# ========================
#  Performing calculations for step  1296
# ========================
#  Performing calculations for step  1297
# ========================
#  Performing calculations for step  1298
# ========================
#  Performing calculations for step  1299
# ========================
#  Performing calculations for step  1300
# ========================
#  Performing calculations for step  1301
# ========================
#  Performing calculations for step  1302
# ========================
#  Performing calculations for step  1303
# ========================
#  Performing calculations for step  1304
# ========================
#  Performing calculations for step  1305
# ========================
#  Performing calculations for step  1306
# ========================
#  Performing calculations for step  1307
# ========================
#  Performing calculations for step  1308
# ========================
#  Performing calculations for step  1309
# ========================
#  Performing calculations for step  1310
# ========================
#  Performing calculations for step  1311
# ========================
#  Performing calculations for step  1312
# ========================
#  Performing calculations for step  1313
# ========================
#  Performing calculations for step  1314
# ========================
#  Performing calculations for step  1315
# ========================
#  Performing calculations for step  1316
# ========================
#  Performing calculations for step  1317
# ========================
#  Performing calculations for step  1318
# ========================
#  Performing calculations for step  1319
# ========================
#  Performing calculations for step  1320
# ========================
#  Performing calculations for step  1321
# ========================
#  Performing calculations for step  1322
# ========================
#  Performing calculations for step  1323
# ========================
#  Performing calculations for step  1324
# ========================
#  Performing calculations for step  1325
# ========================
#  Performing calculations for step  1326
# ========================
#  Performing calculations for step  1327
# ========================
#  Performing calculations for step  1328
# ========================
#  Performing calculations for step  1329
# ========================
#  Performing calculations for step  1330
# ========================
#  Performing calculations for step  1331
# ========================
#  Performing calculations for step  1332
# ========================
#  Performing calculations for step  1333
# ========================
#  Performing calculations for step  1334
# ========================
#  Performing calculations for step  1335
# ========================
#  Performing calculations for step  1336
# ========================
#  Performing calculations for step  1337
# ========================
#  Performing calculations for step  1338
# ========================
#  Performing calculations for step  1339
# ========================
#  Performing calculations for step  1340
# ========================
#  Performing calculations for step  1341
# ========================
#  Performing calculations for step  1342
# ========================
#  Performing calculations for step  1343
# ========================
#  Performing calculations for step  1344
# ========================
#  Performing calculations for step  1345
# ========================
#  Performing calculations for step  1346
# ========================
#  Performing calculations for step  1347
# ========================
#  Performing calculations for step  1348
# ========================
#  Performing calculations for step  1349
# ========================
#  Performing calculations for step  1350
# ========================
#  Performing calculations for step  1351
# ========================
#  Performing calculations for step  1352
# ========================
#  Performing calculations for step  1353
# ========================
#  Performing calculations for step  1354
# ========================
#  Performing calculations for step  1355
# ========================
#  Performing calculations for step  1356
# ========================
#  Performing calculations for step  1357
# ========================
#  Performing calculations for step  1358
# ========================
#  Performing calculations for step  1359
# ========================
#  Performing calculations for step  1360
# ========================
#  Performing calculations for step  1361
# ========================
#  Performing calculations for step  1362
# ========================
#  Performing calculations for step  1363
# ========================
#  Performing calculations for step  1364
# ========================
#  Performing calculations for step  1365
# ========================
#  Performing calculations for step  1366
# ========================
#  Performing calculations for step  1367
# ========================
#  Performing calculations for step  1368
# ========================
#  Performing calculations for step  1369
# ========================
#  Performing calculations for step  1370
# ========================
#  Performing calculations for step  1371
# ========================
#  Performing calculations for step  1372
# ========================
#  Performing calculations for step  1373
# ========================
#  Performing calculations for step  1374
# ========================
#  Performing calculations for step  1375
# ========================
#  Performing calculations for step  1376
# ========================
#  Performing calculations for step  1377
# ========================
#  Performing calculations for step  1378
# ========================
#  Performing calculations for step  1379
# ========================
#  Performing calculations for step  1380
# ========================
#  Performing calculations for step  1381
# ========================
#  Performing calculations for step  1382
# ========================
#  Performing calculations for step  1383
# ========================
#  Performing calculations for step  1384
# ========================
#  Performing calculations for step  1385
# ========================
#  Performing calculations for step  1386
# ========================
#  Performing calculations for step  1387
# ========================
#  Performing calculations for step  1388
# ========================
#  Performing calculations for step  1389
# ========================
#  Performing calculations for step  1390
# ========================
#  Performing calculations for step  1391
# ========================
#  Performing calculations for step  1392
# ========================
#  Performing calculations for step  1393
# ========================
#  Performing calculations for step  1394
# ========================
#  Performing calculations for step  1395
# ========================
#  Performing calculations for step  1396
# ========================
#  Performing calculations for step  1397
# ========================
#  Performing calculations for step  1398
# ========================
#  Performing calculations for step  1399
# ========================
#  Performing calculations for step  1400
# ========================
#  Performing calculations for step  1401
# ========================
#  Performing calculations for step  1402
# ========================
#  Performing calculations for step  1403
# ========================
#  Performing calculations for step  1404
# ========================
#  Performing calculations for step  1405
# ========================
#  Performing calculations for step  1406
# ========================
#  Performing calculations for step  1407
# ========================
#  Performing calculations for step  1408
# ========================
#  Performing calculations for step  1409
# ========================
#  Performing calculations for step  1410
# ========================
#  Performing calculations for step  1411
# ========================
#  Performing calculations for step  1412
# ========================
#  Performing calculations for step  1413
# ========================
#  Performing calculations for step  1414
# ========================
#  Performing calculations for step  1415
# ========================
#  Performing calculations for step  1416
# ========================
#  Performing calculations for step  1417
# ========================
#  Performing calculations for step  1418
# ========================
#  Performing calculations for step  1419
# ========================
#  Performing calculations for step  1420
# ========================
#  Performing calculations for step  1421
# ========================
#  Performing calculations for step  1422
# ========================
#  Performing calculations for step  1423
# ========================
#  Performing calculations for step  1424
# ========================
#  Performing calculations for step  1425
# ========================
#  Performing calculations for step  1426
# ========================
#  Performing calculations for step  1427
# ========================
#  Performing calculations for step  1428
# ========================
#  Performing calculations for step  1429
# ========================
#  Performing calculations for step  1430
# ========================
#  Performing calculations for step  1431
# ========================
#  Performing calculations for step  1432
# ========================
#  Performing calculations for step  1433
# ========================
#  Performing calculations for step  1434
# ========================
#  Performing calculations for step  1435
# ========================
#  Performing calculations for step  1436
# ========================
#  Performing calculations for step  1437
# ========================
#  Performing calculations for step  1438
# ========================
#  Performing calculations for step  1439
# ========================
#  Performing calculations for step  1440
# ========================
#  Performing calculations for step  1441
# ========================
#  Performing calculations for step  1442
# ========================
#  Performing calculations for step  1443
# ========================
#  Performing calculations for step  1444
# ========================
#  Performing calculations for step  1445
# ========================
#  Performing calculations for step  1446
# ========================
#  Performing calculations for step  1447
# ========================
#  Performing calculations for step  1448
# ========================
#  Performing calculations for step  1449
# ========================
#  Performing calculations for step  1450
# ========================
#  Performing calculations for step  1451
# ========================
#  Performing calculations for step  1452
# ========================
#  Performing calculations for step  1453
# ========================
#  Performing calculations for step  1454
# ========================
#  Performing calculations for step  1455
# ========================
#  Performing calculations for step  1456
# ========================
#  Performing calculations for step  1457
# ========================
#  Performing calculations for step  1458
# ========================
#  Performing calculations for step  1459
# ========================
#  Performing calculations for step  1460
# ========================
#  Performing calculations for step  1461
# ========================
#  Performing calculations for step  1462
# ========================
#  Performing calculations for step  1463
# ========================
#  Performing calculations for step  1464
# ========================
#  Performing calculations for step  1465
# ========================
#  Performing calculations for step  1466
# ========================
#  Performing calculations for step  1467
# ========================
#  Performing calculations for step  1468
# ========================
#  Performing calculations for step  1469
# ========================
#  Performing calculations for step  1470
# ========================
#  Performing calculations for step  1471
# ========================
#  Performing calculations for step  1472
# ========================
#  Performing calculations for step  1473
# ========================
#  Performing calculations for step  1474
# ========================
#  Performing calculations for step  1475
# ========================
#  Performing calculations for step  1476
# ========================
#  Performing calculations for step  1477
# ========================
#  Performing calculations for step  1478
# ========================
#  Performing calculations for step  1479
# ========================
#  Performing calculations for step  1480
# ========================
#  Performing calculations for step  1481
# ========================
#  Performing calculations for step  1482
# ========================
#  Performing calculations for step  1483
# ========================
#  Performing calculations for step  1484
# ========================
#  Performing calculations for step  1485
# ========================
#  Performing calculations for step  1486
# ========================
#  Performing calculations for step  1487
# ========================
#  Performing calculations for step  1488
# ========================
#  Performing calculations for step  1489
# ========================
#  Performing calculations for step  1490
# ========================
#  Performing calculations for step  1491
# ========================
#  Performing calculations for step  1492
# ========================
#  Performing calculations for step  1493
# ========================
#  Performing calculations for step  1494
# ========================
#  Performing calculations for step  1495
# ========================
#  Performing calculations for step  1496
# ========================
#  Performing calculations for step  1497
# ========================
#  Performing calculations for step  1498
# ========================
#  Performing calculations for step  1499

# %% [markdown]
# # 5. Plotting machine-learned energies <a name="plot_data"></a>
# [Back to TOC](#toc)
#
# Let's plot the machine-learned energies vs time using `matplotlib`, `scipy.sparse`, and `numpy`. This is similar as in
# [step 3](../../../8_step3).

# %%
# %matplotlib inline
fs = 24
plt.rcParams.update({'font.size': fs})
plt.figure(figsize=(3.21*3, 2.41*3))
# reading the energies
energies = []
for step in range(1000,1500):
    tmp = np.diag(sp.load_npz(f"{params['res_dir']}/E_ks_{step}.npz").real.todense())
    tmp = tmp[0:int(tmp.shape[0]/2)] # Only the energies of alpha orbitals
    energies.append(tmp)
energies = np.array(energies)*units.au2ev
for i in range(energies.shape[1]):
    plt.plot(energies[:,i], lw=2.0)
plt.title('Molecular Orbital Energies')
plt.ylabel('Energy, eV')
plt.xlabel('Time, fs')
plt.tight_layout()
